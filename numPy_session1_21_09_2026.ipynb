# %% [markdown]
# <a href="https://colab.research.google.com/github/soumyadipk03/e-assets/blob/main/numPy_session1_21_09_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Learning NumPy**
# Session 1
